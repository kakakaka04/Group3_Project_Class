# %%
"""
Group 3
Student NAme: Sui Hong, Yeung / Zee, Azhar
Date: Dem. 12, 2022
This program is created for Alberta Hospital (AH). There are 5 classes, each one possesses several functions or methods.
First, we ask for users to input 1-4 to select which class they want to interact with. After that, we ask for inputs about
the things they would like to do such as displaying, searching, changing, or editing data. After showing the outputs such as a list of 
information, added and edited data, and the specific data users are looking for, the program will automatically go back to the 
previous page by using a function in class Management. The program keeps running until the users input a 0 on the main menu.
"""

from tabulate import tabulate
#Class 1 start ---------------------------------------------------Doctor--------------------------------------------------------------
class Doctor:

  #Combine all strings in a list with a "_"
  def formatDrInfo(dr_list):
    return "_".join(dr_list)

  #Collect a new doctor's info
  def enterDrInfo():
    new_dr_info = []
    new_dr_info.append(input("Enter the doctor’s ID:\n" + ""))
    new_dr_info.append(input("Enter the doctor’s name:\n" + ""))
    new_dr_info.append(input("Enter the doctor’s specility:\n" + ""))
    new_dr_info.append(input("Enter the doctor’s timing (e.g., 7am-10pm):\n" + ""))
    new_dr_info.append(input("Enter the doctor’s qualification:\n" + ""))
    new_dr_info.append(input("Enter the doctor’s room number:\n" + ""))
    return new_dr_info

  #Read the doctor file
  def readDoctorsFile():
    doctors_list = []
    doctors_raw_data = open("/content/doctors.txt", "r")
    doctors_raw_data2 = doctors_raw_data.readlines()
    a = 0
    for line in doctors_raw_data2:
      doctors_list.append(doctors_raw_data2[a].rstrip().split('_'))
      a += 1
    del(doctors_list[0])
    return doctors_list

  #Search a specific doctor using the ID
  def searchDoctorById(ID):
    a = 0
    doctors_list = Doctor.readDoctorsFile()
    for line in doctors_list:
      if doctors_list[a][0] == (ID):
        return True
      else:
        a += 1
  
  #Search a specific doctor using the name
  def searchDoctorByName(name):
    a = 0
    doctors_list = Doctor.readDoctorsFile()
    for line in doctors_list:
      if doctors_list[a][1] == (name):
        return True
      else:
        a += 1
  
  #To print a doctor's info from a list as a table using either ID or name
  def displayDoctorInfo(id_or_name):
    header = ["ID", "Name", "Speciality", "Timing", "Qualification", "Room Number"]
    from tabulate import tabulate
    a = 0
    doctors_list = Doctor.readDoctorsFile()
    input_type = id_or_name.isnumeric()
    if input_type == True:
      for item in doctors_list:
        if id_or_name == doctors_list[a][0]:
          print(tabulate([item], headers = header))
          break
        else:
          a += 1
    else:
      for item in doctors_list:
        if id_or_name == doctors_list[a][1]:
          print(tabulate([item], headers = header))
          break
        else:
          a += 1

  #Edit a doctor's info (using the input of ID to locate the doctor from a file)
  def editDoctorInfo():
    doctors_list = Doctor.readDoctorsFile()
    new_dr_info = [0, 0, 0, 0, 0, 0]
    input_dr = input("Please enter the id of the doctor that you want to edit their information:\n" + "")
    yes_no = Doctor.searchDoctorById(input_dr)
    #Check each line to find the doctor that possesses the ID inputted
    a = 0
    if yes_no == True:
      while True:
        if doctors_list[a][0] == input_dr:
          new_dr_info[1] = input("Enter new Name:\n" + "")
          new_dr_info[2] = input("Enter new Specilist in:\n" + "")
          new_dr_info[3] = input("Enter new Timing:\n" + "")
          new_dr_info[4] = input("Enter new Qualification:\n" + "")
          new_dr_info[5] = input("Enter new Room number:\n" + "")
          dr_raw_data = open("/content/doctors.txt", "r")
          item = dr_raw_data.read()
          item = item.replace(doctors_list[a][1], new_dr_info[1])
          item = item.replace(doctors_list[a][2], new_dr_info[2])
          item = item.replace(doctors_list[a][3], new_dr_info[3])
          item = item.replace(doctors_list[a][4], new_dr_info[4])
          item = item.replace(doctors_list[a][5], new_dr_info[5])
          dr_raw_data.close()
          dr_raw_data = open("/content/doctors.txt", "w")
          dr_raw_data.write(item)
          dr_raw_data.close()
          break
        else:
          a += 1
    else:
      print("Can't find the doctor with the same ID on the system")

  #Display the doctors' info from a file as a table 
  def displayDoctorsList():
    doctors_list = []
    doctors_raw_data = open("/content/doctors.txt", "r")
    doctors_raw_data2 = doctors_raw_data.readlines()
    a = 0
    for line in doctors_raw_data2:
      doctors_list.append(doctors_raw_data2[a].rstrip().split('_'))
      a += 1
    del(doctors_list[0])
    header = ["ID", "Name", "Speciality", "Timing", "Qualification", "Room Number"]
    print(tabulate(doctors_list, headers = header))
    doctors_raw_data.close

  #Write a list of doctors' into a file
  def writeListOfDoctorsToFile(new_dr_list):
    a = 0
    for x in new_dr_list:
      new_doctor_list_info = "_".join(new_dr_list[a])
      doctors_raw_data = open("/content/doctors.txt", "a")
      doctors_raw_data.write(f"\n{new_doctor_list_info}")
      doctors_raw_data.close()
      a += 1

  #Add a new doctor's info into a file
  def addDrToFile(new_dr):
    new_doctor = "_".join(new_dr)
    doctors_raw_data = open("/content/doctors.txt", "a")
    doctors_raw_data.write(f"\n{new_doctor}")
    doctors_raw_data.close()
#Class 1 end------------------------------------------------------Doctor--------------------------------------------------------------

#Class 2 start----------------------------------------------------Facility------------------------------------------------------------
class Facility:

  #Open the file and display the failities as a table
  def displayFacilities():
    facility_raw_data = open("/content/facilities.txt", "r")
    facility_raw_data2 = facility_raw_data.readlines()
    for line in facility_raw_data2:
      print(line)
    facility_raw_data.close()

  #Add a new facility to the filw
  def addFacility(new_facility):
    facility_raw_data = open("/content/facilities.txt", "a")
    facility_raw_data.write(f"\n{new_facility}")
    facility_raw_data.close()

  #Write a list of facilities into a file
  def writeListOffacilitiesToFile(new_facility_list):
    a = 0
    facility_raw_data = open("/content/facilities.txt", "a")
    for b in new_facility_list:
      facility_raw_data.write(f"\n{new_facility_list[a]}")
      a += 1
    facility_raw_data.close()
#Class 2 End------------------------------------------------------Facility------------------------------------------------------------

#Class 3 start----------------------------------------------------Laboratory----------------------------------------------------------
class Laboratory:

  #Read the labs' info
  def readLaboratoriesFile():
    lab_list = []
    lab_raw_data = open("/content/laboratories.txt", "r")
    lab_raw_data2 = lab_raw_data.readlines()
    a = 0
    for line in lab_raw_data2:
      lab_list.append(lab_raw_data2[a].rstrip().split('_'))
      a += 1
    del(lab_list[0])
    lab_raw_data.close
    return lab_list

  #Display the lab's info as a table
  def displayLabsList():
    header = ["Facility", "Cost"]
    lab_list2 = Laboratory.readLaboratoriesFile()
    print(tabulate(lab_list2, headers = header))
    
  #Write a list of labs to the file
  def writeListOfLabsToFile(new_lab_list):
    a = 0
    lab_raw_data = open("/content/doctors.txt", "a")
    for x in new_lab_list:
      new_doctor_list_info = "_".join(new_lab_list[a])
      lab_raw_data.write(f"\n{new_doctor_list_info}")
      a += 1
    lab_raw_data.close()
      
  #Combine all strings in a list with "_"
  def formatLabInfo(lab_list):
    return "_".join(lab_list)

  #collect and return a list of a lab's info
  def enterLaboratoryInfo():
    new_lab = []
    new_lab.append(input("Enter Laboratory facility:\n" + ""))
    new_lab.append(input("Enter Laboratory cost:\n" + ""))
    return new_lab

  #Put a lab's info into a file
  def addLabToFile(new_lab):
    add_new_lab = "_".join(new_lab)
    lab_raw_data = open("/content/laboratories.txt", "a")
    lab_raw_data.write(f"\n{add_new_lab}")
    lab_raw_data.close()
#Class 3 end------------------------------------------------------Laboratory----------------------------------------------------------

#Class 4 start----------------------------------------------------Patient-------------------------------------------------------------
class Patient:

  #Combine all strings in a list with "_"
  def formatPatientInfo(patient):
    return "_".join(patient)
  
  #Ask for a patient's info and return it
  def enterPatientInfo():
    new_patient_info = []
    new_patient_info.append(input("Enter Patient id:\n" + ""))
    new_patient_info.append(input("Enter Patient name:\n" + ""))
    new_patient_info.append(input("Enter Patient disease:\n" + ""))
    new_patient_info.append(input("Enter Patient gender:\n" + ""))
    new_patient_info.append(input("Enter Patient age:\n" + ""))
    return new_patient_info
  
  #read the data inside a file
  def readPatientsFile():
    patient_list = []
    patient_raw_data = open("/content/patients.txt", "r")
    patient_raw_data2 = patient_raw_data.readlines()
    a = 0
    for line in patient_raw_data2:
      patient_list.append(patient_raw_data2[a].rstrip().split('_'))
      a += 1
    del(patient_list[0])
    return patient_list

  #check if a ID is valid
  def searchPatientById(ID):
    a = 0
    patient_list = Patient.readPatientsFile()
    for line in patient_list:
      if patient_list[a][0] == (ID):
        return True
      else:
        a += 1

  #Display a patient's info (using the ID to locate the patient)
  def displayPatientInfo(ID):
    header = ["ID", "Name", "Disease", "Gender", "Age"]
    from tabulate import tabulate
    a = 0
    patient_list = Patient.readPatientsFile()
    for item in patient_list:
      if ID in patient_list[a][0]:
        print(tabulate([item], headers = header))
        break
      else:
        a += 1
    
  #change a patient's info based on the inputs
  def editPatientInfo():
    patient_list = Patient.readPatientsFile()
    new_patient = [0, 0, 0, 0, 0]
    input_ID = input("Please enter the id of the Patient that you want to edit their information:\n" + "")
    yes_no = Patient.searchPatientById(input_ID)
    a = 0
    if yes_no == True:
      while True:
        if patient_list[a][0] == input_ID:
          new_patient[1] = input("Enter new Name:\n" + "")
          new_patient[2] = input("Enter new disease:\n" + "")
          new_patient[3] = input("Enter new gender:\n" + "")
          new_patient[4] = input("Enter new age:\n" + "")
          patient_info = open("/content/patients.txt", "r")
          item = patient_info.read()
          item = item.replace(patient_list[a][1], new_patient[1])
          item = item.replace(patient_list[a][2], new_patient[2])
          item = item.replace(patient_list[a][3], new_patient[3])
          item = item.replace(patient_list[a][4], new_patient[4])
          patient_info.close()
          patient_info = open("/content/patients.txt", "w")
          patient_info.write(item)
          patient_info.close()
          break
        else:
          a += 1
    else:
      print("Can't find the Patient with the same id on the system")
    
  #Display all patients' info as a talbe
  def displayPatientsList():
    patient_list = []
    patient_raw_data = open("/content/patients.txt", "r")
    patient_raw_data2 = patient_raw_data.readlines()
    a = 0
    for line in patient_raw_data2:
      patient_list.append(patient_raw_data2[a].rstrip().split('_'))
      a += 1
    del(patient_list[0])
    header = ["ID", "Name", "Disease", "Gender", "Age"]
    print(tabulate(patient_list, headers = header))

  #Add a list of patients' info into the file
  def writeListOfPatientsToFile(new_patients_list):
    patient_raw_data = open("/content/patients.txt", "a")
    a = 0
    for b in new_patients_list:
      new_patient_list_info = "_".join(new_patients_list[a])
      patient_raw_data.write(f"\n{new_patient_list_info}")
      a += 1
    patient_raw_data.close()

  #Add a patient's info to a file
  def addPatientToFile(new_patient):
    new_patient_info = "_".join(new_patient)
    patient_raw_data = open("/content/patients.txt", "a")
    patient_raw_data.write(f"\n{new_patient_info}")
    patient_raw_data.close()
#Class 4 end------------------------------------------------------Patient---------------------------------------------------------------

#Class 5 start----------------------------------------------------Management------------------------------------------------------------
class Management:
  #Bring users back to the previous page using the inputs
  def DisplayMenu(layer1, layer2):
    if (layer1, layer2) == (1, 6) or (layer1, layer2) == (2, 3) or (layer1, layer2) == (3, 3) or (layer1, layer2) == (4, 5):
      pass
    else:
      print("Back to the previous page.")
      return a.append(0)
#Class 5 end------------------------------------------------------Management------------------------------------------------------------

#Start
#Ask users which class they want to navigate, and only stop the program when users input "0" 
while True:
  print("Welcome to Alberta Hospital (AH) Managment system ")
  input_action = input("Select from the following options, or select 0 to stop:\n" + 
                      "1 - 	Doctors\n" +
                      "2 - 	Facilities\n" +
                      "3 - 	Laboratories\n" +
                      "4 - 	Patients\n" + "")
  if input_action == "0":
    break

  else:
    a = [0]
    for loop in a:
      if input_action == "1": #Enter class Doctor
        input_action2 = input("Doctors Menu:\n" +
                              "1 - Display Doctors list\n" +
                              "2 - Search for doctor by ID\n" +
                              "3 - Search for doctor by name\n" +
                              "4 - Add doctor\n" +
                              "5 - Edit doctor info\n" +
                              "6 - Back to the Main Menu\n" + "")
        
        if input_action2 == "1": #Display doctor list
          Doctor.displayDoctorsList()
        elif input_action2 == "2": #Display a doctor's info based on the input (ID)
          input_dr_id = input("Enter the doctor ID:\n" + "")
          if Doctor.searchDoctorById(input_dr_id) == True:
            Doctor.displayDoctorInfo(input_dr_id)
          else:
            print("Can't find the doctor with the same ID on the system")
        elif input_action2 == "3": #Display a doctor's info based on the input (name)
          input_dr_name = input("Enter the doctor name:\n" + "")
          if Doctor.searchDoctorByName(input_dr_name) == True:
            Doctor.displayDoctorInfo(input_dr_name)
          else:
            print("Can't find the doctor with the same name on the system")
        elif input_action2 == "4": #Add a new doctor to a file
          new_doctor = Doctor.enterDrInfo()
          Doctor.addDrToFile(new_doctor)
        elif input_action2 == "5": #Edit a doctor
          new_doctor = Doctor.editDoctorInfo()
        elif input_action2 == "6": #back to the previous page
          break

      elif input_action == "2": #Enter class Facility - 
        input_action2 = input("Facilities Menu:\n" +
                               "1 - Display Facilities list\n" +
                               "2 - Add Facility\n" +
                               "3 - Back to the Main Menu\n" + "")
        
        if input_action2 == "1": #Display the facility list
          Facility.displayFacilities()
        elif input_action2 == "2": #Add a new facility
          new_facility = input("Enter Facility name:\n" + "")
          Facility.addFacility(new_facility)
        elif input_action2 == "3": #back to the previous page
          break

      elif input_action =="3": #Enter class Laboratory
        input_action2 = input("Laboratories Menu:\n" +
                           "1 - Display laboratories list\n" +
                           "2 - Add laboratory\n" +
                           "3 - Back to the Main Menu\n" + "")
        
        if input_action2 == "1": #Display the laboratory list
          Laboratory.displayLabsList()
        elif input_action2 == "2": #Add a new lab to a file
          new_lab = Laboratory.enterLaboratoryInfo()
          Laboratory.addLabToFile(new_lab)
        elif input_action2 =="3": #back to the previous page
          break
      
      elif input_action =="4": #Enter class Patient
        input_action2 = input("Patients Menu:\n" +
                              "1 - Display patients list\n" +
                              "2 - Search for patient by ID\n" +
                              "3 - Add patient\n" +
                              "4 - Edit patient info\n" +
                              "5 - Back to the Main Menu\n" + "")
        
        if input_action2 == "1": #display the patient list
          Patient.displayPatientsList()
        elif input_action2 == "2": #display a patient's info based on the input (ID)
          patient_ID = input("Enter the Patient Id:\n" + "")
          if Patient.searchPatientById(patient_ID) == True:
            Patient.displayPatientInfo(patient_ID)
          else:
            print("Can't find the Patient with the same id on the system.")
        elif input_action2 == "3": #Add a patient's info to a file
          new_patient = Patient.enterPatientInfo()
          Patient.addPatientToFile(new_patient)
        elif input_action2 == "4": #edit a patient's info from the file
          Patient.editPatientInfo()
        elif input_action2 == "5": #back to the previous page
          break
      Management.DisplayMenu(input_action, input_action2)
# Out:
# Welcome to Alberta Hospital (AH) Managment system
# Select from the following options, or select 0 to stop:
# 1 - 	Doctors
# 2 - 	Facilities
# 3 - 	Laboratories
# 4 - 	Patients
# 1
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 1
#   ID  Name       Speciality    Timing    Qualification      Room Number
# ----  ---------  ------------  --------  ---------------  -------------
#   21  Dr.Gody    ENT           5-11AM    MBBS,MD                     17
#   32  Dr.Vikram  Physician     10-3AM    MBBS,MD                     45
#   17  Dr.Amy     Surgeon       8-2AM     BDM                          8
#   33  Dr.David   Artho         10-4PM    MBBS,MS                     40
#  123  Dr. Ross   Headackes     8-10am    Mst                        102
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 2
# Enter the doctor ID:
# 123
#   ID  Name      Speciality    Timing    Qualification      Room Number
# ----  --------  ------------  --------  ---------------  -------------
#  123  Dr. Ross  Headackes     8-10am    Mst                        102
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 3
# Enter the doctor name:
# Dr.Amy
#   ID  Name    Speciality    Timing    Qualification      Room Number
# ----  ------  ------------  --------  ---------------  -------------
#   17  Dr.Amy  Surgeon       8-2AM     BDM                          8
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 2
# Enter the doctor ID:
# 222222
# Can't find the doctor with the same ID on the system
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 3
# Enter the doctor name:
# jason
# Can't find the doctor with the same name on the system
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 4
# Enter the doctor’s ID:
# 321
# Enter the doctor’s name:
# Jason
# Enter the doctor’s specility:
# Nothing
# Enter the doctor’s timing (e.g., 7am-10pm):
# 1pm-2pm
# Enter the doctor’s qualification:
# Mum&Dad
# Enter the doctor’s room number:
# 101
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 1
#   ID  Name       Speciality    Timing    Qualification      Room Number
# ----  ---------  ------------  --------  ---------------  -------------
#   21  Dr.Gody    ENT           5-11AM    MBBS,MD                     17
#   32  Dr.Vikram  Physician     10-3AM    MBBS,MD                     45
#   17  Dr.Amy     Surgeon       8-2AM     BDM                          8
#   33  Dr.David   Artho         10-4PM    MBBS,MS                     40
#  123  Dr. Ross   Headackes     8-10am    Mst                        102
#  321  Jason      Nothing       1pm-2pm   Mum&Dad                    101
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 5
# Please enter the id of the doctor that you want to edit their information:
# 321
# Enter new Name:
# Jason Y
# Enter new Specilist in:
# nothing
# Enter new Timing:
# 2pm-3pm
# Enter new Qualification:
# Mum&Dad
# Enter new Room number:
# 101
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 1
#   ID  Name       Speciality    Timing    Qualification      Room Number
# ----  ---------  ------------  --------  ---------------  -------------
#   21  Dr.Gody    ENT           5-11AM    MBBS,MD                     17
#   32  Dr.Vikram  Physician     10-3AM    MBBS,MD                     45
#   17  Dr.Amy     Surgeon       8-2AM     BDM                          8
#   33  Dr.David   Artho         10-4PM    MBBS,MS                     40
#  123  Dr. Ross   Headackes     8-10am    Mst                        102
#  321  Jason Y    nothing       2pm-3pm   Mum&Dad                    101
# Back to the previous page.
# Doctors Menu:
# 1 - Display Doctors list
# 2 - Search for doctor by ID
# 3 - Search for doctor by name
# 4 - Add doctor
# 5 - Edit doctor info
# 6 - Back to the Main Menu
# 6
# Welcome to Alberta Hospital (AH) Managment system
# Select from the following options, or select 0 to stop:
# 1 - 	Doctors
# 2 - 	Facilities
# 3 - 	Laboratories
# 4 - 	Patients
# 2
# Facilities Menu:
# 1 - Display Facilities list
# 2 - Add Facility
# 3 - Back to the Main Menu
# 1
# Hospital  Facility are:
#
# Ambulance
#
# Admit Facility
#
# Canteen
#
# Emergency
# Back to the previous page.
# Facilities Menu:
# 1 - Display Facilities list
# 2 - Add Facility
# 3 - Back to the Main Menu
# 2
# Enter Facility name:
# covid care
# Back to the previous page.
# Facilities Menu:
# 1 - Display Facilities list
# 2 - Add Facility
# 3 - Back to the Main Menu
# 1
# Hospital  Facility are:
#
# Ambulance
#
# Admit Facility
#
# Canteen
#
# Emergency
#
# covid care
# Back to the previous page.
# Facilities Menu:
# 1 - Display Facilities list
# 2 - Add Facility
# 3 - Back to the Main Menu
# 3
# Welcome to Alberta Hospital (AH) Managment system
# Select from the following options, or select 0 to stop:
# 1 - 	Doctors
# 2 - 	Facilities
# 3 - 	Laboratories
# 4 - 	Patients
# 3
# Laboratories Menu:
# 1 - Display laboratories list
# 2 - Add laboratory
# 3 - Back to the Main Menu
# 1
# Facility      Cost
# ----------  ------
# Facility1      800
# Facility2     1200
# Facility3      500
# Facility4       50
# Back to the previous page.
# Laboratories Menu:
# 1 - Display laboratories list
# 2 - Add laboratory
# 3 - Back to the Main Menu
# 2
# Enter Laboratory facility:
# lab5
# Enter Laboratory cost:
# 1234
# Back to the previous page.
# Laboratories Menu:
# 1 - Display laboratories list
# 2 - Add laboratory
# 3 - Back to the Main Menu
# 1
# Facility      Cost
# ----------  ------
# Facility1      800
# Facility2     1200
# Facility3      500
# Facility4       50
# lab5          1234
# Back to the previous page.
# Laboratories Menu:
# 1 - Display laboratories list
# 2 - Add laboratory
# 3 - Back to the Main Menu
# 3
# Welcome to Alberta Hospital (AH) Managment system
# Select from the following options, or select 0 to stop:
# 1 - 	Doctors
# 2 - 	Facilities
# 3 - 	Laboratories
# 4 - 	Patients
# 4
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 1
#   ID  Name    Disease    Gender      Age
# ----  ------  ---------  --------  -----
#   12  Pankaj  Cancer     Male         30
#   13  Sumit   Cold       Male         23
#   14  Alok    Maleriya   Male         45
#   15  Ravi    Diabetes   Male         25
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 2
# Enter the Patient Id:
# 13
#   ID  Name    Disease    Gender      Age
# ----  ------  ---------  --------  -----
#   13  Sumit   Cold       Male         23
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 2
# Enter the Patient Id:
# 111
# Can't find the Patient with the same id on the system.
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 3
# Enter Patient id:
# 16
# Enter Patient name:
# Jason
# Enter Patient disease:
# sleepy
# Enter Patient gender:
# male
# Enter Patient age:
# 80
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 1
#   ID  Name    Disease    Gender      Age
# ----  ------  ---------  --------  -----
#   12  Pankaj  Cancer     Male         30
#   13  Sumit   Cold       Male         23
#   14  Alok    Maleriya   Male         45
#   15  Ravi    Diabetes   Male         25
#   16  Jason   sleepy     male         80
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 4
# Please enter the id of the Patient that you want to edit their information:
# 16
# Enter new Name:
# Jason
# Enter new disease:
# sleepy
# Enter new gender:
# male
# Enter new age:
# 88
# Back to the previous page.
# Patients Menu:
# 1 - Display patients list
# 2 - Search for patient by ID
# 3 - Add patient
# 4 - Edit patient info
# 5 - Back to the Main Menu
# 5
# Welcome to Alberta Hospital (AH) Managment system
# Select from the following options, or select 0 to stop:
# 1 - 	Doctors
# 2 - 	Facilities
# 3 - 	Laboratories
# 4 - 	Patients
# 0
